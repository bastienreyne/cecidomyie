# %% [markdown]
# # OPTIMISATION 2
#
# Dans les scripts, comme dans le poster, on note :
# * A $\Leftrightarrow$ Enherbement Bas
# * B $\Leftrightarrow$ Bachage
# * C $\Leftrightarrow$ Enherbement Haut
#
# Algo de descente de gradient pour l'estimation du parametre $\psi$. Optimisation sur le nombre d'inflorescences..

# %%
import os 
import numpy as np
import matplotlib.pyplot as plt

os.chdir("../Fonctions")

from Datas import *
import FunModele as mdl
import FunOptimisation2 as opt2
import FunObj as obj
from Bounds2 import *

# %%
psi = 102

params = [psi]
args = [new_A,new_B,new_C]

# %%
## Fonction objectif = RRMSE

# Normalisation 1
res, It_A, Lt_A, Lt_p_A, Nt_A, It_B, Lt_B, Lt_p_B, Nt_B, It_C, Lt_C, Lt_p_C, Nt_C = opt2.visual_opt_bis(params,args,obj.RRMSE,I_A_pie,I_B_pie,I_C_pie,mybounds2_1,1,0)

plt.plot(Lt_A[xJoursA])
plt.plot(L_A[xJoursA])
plt.show()

plt.plot(Lt_B[xJoursB])
plt.plot(L_B[xJoursB])
plt.show()

plt.plot(Lt_C[xJoursC])
plt.plot(L_C[xJoursC])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-66a91a9a4fb9> in <module>()
#      12 plt.show()
#      13
# ---> 14 plt.plot(Lt[xJoursC])
#      15 plt.plot(L_C[xJoursC])
#      16 plt.show()
#
# NameError: name 'Lt' is not defined

# %%
list_ = [round(x,2) for x in res.x]

# %%
print (list_)
print (res)
