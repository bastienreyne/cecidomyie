# %% [markdown]
# # OPTIMISATION
#
# Dans les scripts, comme dans le poster, on note :
# * A $\Leftrightarrow$ Enherbement Bas
# * B $\Leftrightarrow$ Bachage
# * C $\Leftrightarrow$ Enherbement Haut
#
# Population de cecido exogene en fonction du nombre d'inflorescences
#
# Dispersion égale pour les sous parcelles voisines
#
# Algo du recuit simulé

# %%
import os 
import numpy as np
import matplotlib.pyplot as plt

os.chdir("../Fonctions")

from Datas import *
import FunModele as mdl
import FunOptimisation as opt
import FunObj as obj
from Bounds import *

# %%
lambda_  = 0.27
mu_MS_C_ = 0.11
pl_      = 0.51
k_       = 0.38
beta_    = 1

params = [lambda_,mu_MS_C_,pl_,k_,beta_]
args = [TotJours,I_A_pie,I_B_pie,I_C_pie,d_l,E,mu,p_pup,d_p,mdl.popExo2,mdl.out1]

# %%
## Fonction objectif = MAE

# Pas de normalisation
res_1, Lt_A_1, Lt_p_A_1, Nt_A_1, Lt_B_1, Lt_p_B_1, Nt_B_1, Lt_C_1, Lt_p_C_1, Nt_C_1 = opt.visual_opt_bis(params,args,obj.MAE,L_A,L_B,L_C,mybounds1,1,0)

# Normalisation 1
res_2, Lt_A_2, Lt_p_A_2, Nt_A_2, Lt_B_2, Lt_p_B_2, Nt_B_2, Lt_C_2, Lt_p_C_2, Nt_C_2 = opt.visual_opt_bis(params,args,obj.MAE_1,L_A,L_B,L_C,mybounds1,1,0)

# Normalisation 2
res_3, Lt_A_3, Lt_p_A_3, Nt_A_3, Lt_B_3, Lt_p_B_3, Nt_B_3, Lt_C_3, Lt_p_C_3, Nt_C_3 = opt.visual_opt_bis(params,args,obj.MAE_2,L_A,L_B,L_C,mybounds1,1,0)

# %%
## Fonction objectif = MSE

# Pas de normalisation
res_5, Lt_A_5, Lt_p_A_5, Nt_A_5, Lt_B_5, Lt_p_B_5, Nt_B_5, Lt_C_5, Lt_p_C_5, Nt_C_5 = opt.visual_opt_bis(params,args,obj.MSE,L_A,L_B,L_C,mybounds1,1,0)

# Normalisation 1
res_6, Lt_A_6, Lt_p_A_6, Nt_A_6, Lt_B_6, Lt_p_B_6, Nt_B_6, Lt_C_6, Lt_p_C_6, Nt_C_6 = opt.visual_opt_bis(params,args,obj.MSE_1,L_A,L_B,L_C,mybounds1,0,1)

# Normalisation 2
res_7, Lt_A_7, Lt_p_A_7, Nt_A_7, Lt_B_7, Lt_p_B_7, Nt_B_7, Lt_C_7, Lt_p_C_7, Nt_C_7 = opt.visual_opt_bis(params,args,obj.MSE_2,L_A,L_B,L_C,mybounds1,0,1)

# %%
## Fonction objectif = RMSE

# Pas de normalisation
res_9, Lt_A_9, Lt_p_A_9, Nt_A_9, Lt_B_9, Lt_p_B_9, Nt_B_9, Lt_C_9, Lt_p_C_9, Nt_C_9 = opt.visual_opt_bis(params,args,obj.RMSE,L_A,L_B,L_C,mybounds1,1,0)

# Normalisation 1
res_10, Lt_A_10, Lt_p_A_10, Nt_A_10, Lt_B_10, Lt_p_B_10, Nt_B_10, Lt_C_10, Lt_p_C_10, Nt_C_10 = opt.visual_opt_bis(params,args,obj.RMSE_1,L_A,L_B,L_C,mybounds1,1,0)

# Normalisation 2
res_11, Lt_A_11, Lt_p_A_11, Nt_A_11, Lt_B_11, Lt_p_B_11, Nt_B_11, Lt_C_11, Lt_p_C_11, Nt_C_11 = opt.visual_opt_bis(params,args,obj.RMSE_2,L_A,L_B,L_C,mybounds1,1,0)

# %%
## Fonction objectif = RRMSE

res_13, Lt_A_13, Lt_p_A_13, Nt_A_13, Lt_B_13, Lt_p_B_13, Nt_B_13, Lt_C_13, Lt_p_C_13, Nt_C_13 = opt.visual_opt_bis(params,args,obj.RRMSE,L_A,L_B,L_C,mybounds1,1,0)

# %%
## Fonction objectif = PCC

res_14, Lt_A_14, Lt_p_A_14, Nt_A_14, Lt_B_14, Lt_p_B_14, Nt_B_14, Lt_C_14, Lt_p_C_14, Nt_C_14 = opt.visual_opt_bis(params,args,obj.PCC,L_A,L_B,L_C,mybounds1,1,0)

# %%
## Fonction objectif = D

res_15, Lt_A_15, Lt_p_A_15, Nt_A_15, Lt_B_15, Lt_p_B_15, Nt_B_15, Lt_C_15, Lt_p_C_15, Nt_C_15 = opt.visual_opt_bis(params,args,obj.D,L_A,L_B,L_C,mybounds1,1,0)

# %%
## Fonction objectif = NSE

res_16, Lt_A_16, Lt_p_A_16, Nt_A_16, Lt_B_16, Lt_p_B_16, Nt_B_16, Lt_C_16, Lt_p_C_16, Nt_C_16 = opt.visual_opt_bis(params,args,obj.NSE,L_A,L_B,L_C,mybounds1,1,0)

# %%
list1  = [round(x,2) for x in res_1.x]
list2  = [round(x,2) for x in res_2.x]
list3  = [round(x,2) for x in res_3.x]
list5  = [round(x,2) for x in res_5.x]
list6  = [round(x,2) for x in res_6.x]
list7  = [round(x,2) for x in res_7.x]
list9  = [round(x,2) for x in res_9.x]
list10 = [round(x,2) for x in res_10.x]
list11 = [round(x,2) for x in res_11.x]
list13 = [round(x,2) for x in res_13.x]
list14 = [round(x,2) for x in res_14.x]
list15 = [round(x,2) for x in res_15.x]
list16 = [round(x,2) for x in res_16.x]

# %%
print (list1)
print (list2)
print (list3)
print (list5)
print (list6)
print (list9)
print (list10)
print (list11)
print (list13)
print (list14)
print (list15)
print (list16)
# Out:
# [0.08, 0.16, 0.83, 0.37]
# [0.06, 0.49, 0.56, 0.8]
# [0.27, 0.11, 0.51, 0.38]
# [0.08, 0.13, 0.89, 0.41]
# [0.18, 0.49, 0.97, 0.21]
# [0.2, 0.31, 0.91, 0.17]
# [0.26, 0.27, 0.57, 0.04]
# [0.6, 0.24, 1.0, 0.48]
# [0.3, 0.04, 0.59, 0.7]
# [0.42, 0.09, 0.63, 0.23]
# [0.08, 0.04, 0.75, 0.59]
# [0.4, 0.45, 0.6, 0.99]

# %%
list6
# Out:
# [0.18, 0.49, 0.97, 0.21]

# %%
Nt_A_13
# Out:
# array([  74.97349168,  104.96288836,  134.95228503,  164.9416817 ,
#         195.23097234,  225.22036902,  255.20976569,  285.19916237,
#         290.59725377,  295.99534517,  301.39343657,  307.09142194,
#         416.48951334,  462.88760474,  509.28569614,  578.87594108,
#         647.16629205,  715.75653699,  784.34678193,  853.93702687,
#         888.22737785,  924.81762278,  962.10691343, 1000.39620407,
#        1180.68549471, 1274.97478535, 1369.26407599, 1495.55336663,
#        1618.84265727, 1745.13194791, 1852.22696434, 1962.32198078,
#        1963.1383099 , 1966.95463903, 1972.77096815, 1978.58729727,
#        2179.40362639, 2283.61274525, 2386.12175808, 2574.41635039,
#        2759.01083666, 2947.60532293, 3043.89991523, 3043.31709262,
#        2846.73427001, 2650.1514474 , 2486.35738526, 2321.56332312,
#        2158.06915495, 2057.27509281, 1959.48103068, 2025.27615315,
#        2092.37116958, 2164.56438345, 2234.75759733, 2102.65091723,
# ...

# %%
Nt_B_13
# Out:
# array([  60.57858128,   69.27550632,   77.97243135,   86.66935639,
#          95.36628142,  104.06320646,  112.76013149,  121.45705653,
#         123.25642033,  125.3556781 ,  127.1550419 ,  129.25429966,
#         167.05366346,  184.15292123,  199.95228503,  223.54889197,
#         247.1454989 ,  271.74210584,  295.63860674,  319.23521368,
#         331.83182061,  343.42842755,  341.33023011,  339.23203268,
#         386.13383524,  403.33553178,  421.23733434,  448.13913691,
#         477.04093947,  503.94274204,  532.6439084 ,  563.34507477,
#         585.64284807,  608.64072741,  632.93850071,  656.93638004,
#         748.23415334,  785.73680417,  822.53934897,  863.64602907,
#         901.75270916,  941.85938926,  952.96606936, 1005.8540876 ,
#         989.0419998 ,  972.93001805,  947.12111125,  921.31220446,
#         894.50329766,  891.69439087,  887.88548407, 1060.23161918,
#        1233.87764824, 1284.76672682, 1335.35591142, 1317.24499   ,
# ...

# %%
Nt_C_13
# Out:
# array([  42.58494328,   54.28080798,   65.67677872,   77.37264342,
#          89.06850812,  100.76437282,  112.16034356,  123.85620826,
#         128.35461776,  132.85302726,  137.35143676,  142.14974023,
#         183.64814973,  203.14655923,  222.64496874,  243.54252997,
#         266.14019724,  287.03775847,  308.93531971,  330.83288094,
#         339.43054821,  349.32810945,  344.43054821,  341.53298698,
#         387.93531971,  404.03775847,  420.14019724,  447.54252997,
#         473.64496874,  499.7474075 ,  616.91835439,  732.08930127,
#         744.79046764,  759.79152797,  773.49269434,  788.49375467,
#         873.19492103,  903.9995865 ,  935.80425196, 1069.07763761,
#        1201.0511293 , 1334.32451495, 1446.5979006 , 1560.46683285,
#        1598.3357651 , 1634.20469736, 1622.99027683, 1613.47596234,
#        1603.26154182, 1613.74722733, 1624.5328068 , 1824.77120148,
#        2026.30949012, 2134.78033097, 2244.25117182, 2282.42211871,
# ...
