# %% [markdown]
# # OPTIMISATION
#
# Dans les scripts, comme dans le poster, on note :
# * A $\Leftrightarrow$ Enherbement Bas
# * B $\Leftrightarrow$ Bachage
# * C $\Leftrightarrow$ Enherbement Haut
#
# Population de cecido exogene en fonction du nombre d'inflorescences
#
# Dispersion en fonction de la proportion d'inflorescences
#
# Algo du recuit simulé

# %%
import os 
import numpy as np
import matplotlib.pyplot as plt

os.chdir("../Fonctions")

from Datas import *
import FunModele1 as mdl1
import FunOptimisation1 as opt1
import FunObj as obj
from Bounds1 import *

# %%
lambda_  = 0.27
mu_MS_C_ = 0.11
pl_      = 0.51
k_       = 0.38
params = [lambda_,mu_MS_C_,pl_,k_]
args = [I_A_pie,I_B_pie,I_C_pie]

# %%
## Fonction objectif = MAE

# Pas de normalisation
res_1, Lt_A_1, Lt_p_A_1, Nt_A_1, Lt_B_1, Lt_p_B_1, Nt_B_1, Lt_C_1, Lt_p_C_1, Nt_C_1 = opt1.visual_opt_bis(params,args,obj.MAE,L_A,L_B,L_C,mybounds1_1,1,0)

# Normalisation 1
res_2, Lt_A_2, Lt_p_A_2, Nt_A_2, Lt_B_2, Lt_p_B_2, Nt_B_2, Lt_C_2, Lt_p_C_2, Nt_C_2 = opt1.visual_opt_bis(params,args,obj.MAE_1,L_A,L_B,L_C,mybounds1_1,1,0)

# Normalisation 2
res_3, Lt_A_3, Lt_p_A_3, Nt_A_3, Lt_B_3, Lt_p_B_3, Nt_B_3, Lt_C_3, Lt_p_C_3, Nt_C_3 = opt1.visual_opt_bis(params,args,obj.MAE_2,L_A,L_B,L_C,mybounds1_1,1,0)

# %%
## Fonction objectif = MSE

# Pas de normalisation
res_5, Lt_A_5, Lt_p_A_5, Nt_A_5, Lt_B_5, Lt_p_B_5, Nt_B_5, Lt_C_5, Lt_p_C_5, Nt_C_5 = opt1.visual_opt_bis(params,args,obj.MSE,L_A,L_B,L_C,mybounds1_1,1,0)

# Normalisation 1
res_6, Lt_A_6, Lt_p_A_6, Nt_A_6, Lt_B_6, Lt_p_B_6, Nt_B_6, Lt_C_6, Lt_p_C_6, Nt_C_6 = opt1.visual_opt_bis(params,args,obj.MSE_1,L_A,L_B,L_C,mybounds1_1,1,0)

# Normalisation 2
res_7, Lt_A_7, Lt_p_A_7, Nt_A_7, Lt_B_7, Lt_p_B_7, Nt_B_7, Lt_C_7, Lt_p_C_7, Nt_C_7 = opt1.visual_opt_bis(params,args,obj.MSE_2,L_A,L_B,L_C,mybounds1_1,1,0)

# %%
## Fonction objectif = RMSE

# Pas de normalisation
res_9, Lt_A_9, Lt_p_A_9, Nt_A_9, Lt_B_9, Lt_p_B_9, Nt_B_9, Lt_C_9, Lt_p_C_9, Nt_C_9 = opt1.visual_opt_bis(params,args,obj.RMSE,L_A,L_B,L_C,mybounds1_1,1,0)

# Normalisation 1
res_10, Lt_A_10, Lt_p_A_10, Nt_A_10, Lt_B_10, Lt_p_B_10, Nt_B_10, Lt_C_10, Lt_p_C_10, Nt_C_10 = opt1.visual_opt_bis(params,args,obj.RMSE_1,L_A,L_B,L_C,mybounds1_1,1,0)

# Normalisation 2
res_11, Lt_A_11, Lt_p_A_11, Nt_A_11, Lt_B_11, Lt_p_B_11, Nt_B_11, Lt_C_11, Lt_p_C_11, Nt_C_11 = opt1.visual_opt_bis(params,args,obj.RMSE_2,L_A,L_B,L_C,mybounds1_1,1,0)

# %%
## Fonction objectif = RRMSE

res_13, Lt_A_13, Lt_p_A_13, Nt_A_13, Lt_B_13, Lt_p_B_13, Nt_B_13, Lt_C_13, Lt_p_C_13, Nt_C_13 = opt1.visual_opt_bis(params,args,obj.RRMSE,L_A,L_B,L_C,mybounds1_1,1,0)

# %%
list1  = [round(x,2) for x in res_1.x]
list2  = [round(x,2) for x in res_2.x]
list3  = [round(x,2) for x in res_3.x]
list5  = [round(x,2) for x in res_5.x]
list6  = [round(x,2) for x in res_6.x]
list7  = [round(x,2) for x in res_7.x]
list9  = [round(x,2) for x in res_9.x]
list10 = [round(x,2) for x in res_10.x]
list11 = [round(x,2) for x in res_11.x]
list13 = [round(x,2) for x in res_13.x]

# %%
print (list1)
print (list2)
print (list3)
print (list5)
print (list6)
print (list9)
print (list10)
print (list11)
print (list13)
# Out:
# [0.53, 0.45, 0.44, 0.15]
# [0.1, 0.9, 0.72, 0.36]
# [0.23, 0.33, 0.94, 0.57]
# [0.03, 0.19, 0.08, 0.88]
# [0.34, 0.97, 0.53, 0.9]
# [0.08, 0.09, 0.37, 0.32]
# [0.42, 0.98, 0.8, 0.64]
# [0.72, 0.65, 0.34, 0.41]
# [0.6, 0.09, 0.13, 0.39]

# %%
150*0.04
# Out:
# 6.0

# %%
print (list7)
print (list11)
print (list13)
# Out:
# [0.26, 0.36, 0.38, 0.46]
# [0.72, 0.65, 0.34, 0.41]
# [0.6, 0.09, 0.13, 0.39]

# %%
np.sum(Lt_A_3)-np.sum(L_A)
# Out:
# 135399.0

# %%
np.sum(L_A)
# Out:
# 205923
