# %% [markdown]
# # Cinétiques obtenues avec notre modèle

# %%
import os 
import numpy as np
import matplotlib.pyplot as plt

os.chdir("../Fonctions Simulation et Optimisation")

from Datas import *
import FunModele1 as mdl1
import FunOptimisation1 as opt1
import FunObj as obj
import FunNorm as nrm
import FunModele as mdl

# %%
import pylab

# %% [markdown]
# ## GRAPHES

# %%
L_A = L_A[29:len(L_A)]
L_B = L_B[8:len(L_B)]
L_C = L_C[20:len(L_C)]
Lt_A, Lt_p_A, Nt_A, Lt_B, Lt_p_B, Nt_B, Lt_C, Lt_p_C, Nt_C = mdl1.integrateCecidoEchange (0.59, 0.98, 0.44, 0.59, 0.84, TotJours,I_A_pie[29:len(I_A_pie)],I_B_pie[8:len(I_B_pie)],I_C_pie[20:len(I_C_pie)],d_l, E, mu, p_pup, d_p, beta, mdl1.popExo2, mdl1.out2)

# %%
plt.plot(Lt_A[xJoursA],'o-',color="blue",linewidth=2.0)
plt.plot(L_A[xJoursA],'o-',color="black",linewidth=1.0)
plt.ylim(ymax=16000)
plt.yticks(fontsize=14)
plt.xticks(np.array([4,13,21]),("01-Aout","01-Sept","01-Oct"),fontsize=14)
pylab.savefig("S1A.png")
plt.show()

plt.plot(Lt_B[xJoursB],'o-',color="blue",linewidth=2.0)
plt.plot(L_B[xJoursB],'o-',color="black",linewidth=1.0)
plt.ylim(ymax=16000)
plt.yticks(fontsize=14)
plt.xticks(np.array([4,13,21]),("01-Aout","01-Sept","01-Oct"),fontsize=14)
pylab.savefig("S2A.png")
plt.show()

plt.plot(Lt_C[xJoursC],'o-',color="blue",linewidth=2.0)
plt.plot(L_C[xJoursC],'o-',color="black",linewidth=1.0)
plt.ylim(ymax=16000)
plt.yticks(fontsize=14)
plt.xticks(np.array([4,13,21]),("01-Aout","01-Sept","01-Oct"),fontsize=14)
pylab.savefig("S3A.png")
plt.show()

# %%
It_A, Lt_A, Lt_p_A, Nt_A, It_B, Lt_B, Lt_p_B, Nt_B, It_C, Lt_C, Lt_p_C, Nt_C = mdl.integrateCecidoInflo (102, new_A, new_B, new_C)

# %%
plt.plot(Lt_A[xJoursA],'o-',color="blue",linewidth=2.0)
plt.plot(L_A[xJoursA],'o-',color="black",linewidth=1.0)
plt.ylim(ymax=13000)
plt.yticks(fontsize=14)
plt.xticks(np.array([4,13,21]),("01-Aout","01-Sept","01-Oct"),fontsize=14)
pylab.savefig("S2_1A.png")
plt.show()

plt.plot(Lt_B[xJoursB],'o-',color="blue",linewidth=2.0)
plt.plot(L_B[xJoursB],'o-',color="black",linewidth=1.0)
plt.ylim(ymax=13000)
plt.yticks(fontsize=14)
plt.xticks(np.array([4,13,21]),("01-Aout","01-Sept","01-Oct"),fontsize=14)
pylab.savefig("S2_1B.png")
plt.show()

plt.plot(Lt_C[xJoursC],'o-',color="blue",linewidth=2.0)
plt.plot(L_C[xJoursC],'o-',color="black",linewidth=1.0)
plt.ylim(ymax=13000)
plt.yticks(fontsize=14)
plt.xticks(np.array([4,13,21]),("01-Aout","01-Sept","01-Oct"),fontsize=14)
pylab.savefig("S2_1C.png")
plt.show()

# %%
plt.plot(It_A[xJoursA],'o-',color="blue",linewidth=2.0)
plt.plot(I_A_pie[xJoursA],'o-',color="black",linewidth=1.0)
plt.ylim(ymax=6000)
plt.yticks(fontsize=14)
plt.xticks(np.array([4,13,21]),("01-Aout","01-Sept","01-Oct"),fontsize=14)
pylab.savefig("S2_2A.png")
plt.show()

plt.plot(It_B[xJoursB],'o-',color="blue",linewidth=2.0)
plt.plot(I_B_pie[xJoursB],'o-',color="black",linewidth=1.0)
plt.ylim(ymax=6000)
plt.yticks(fontsize=14)
plt.xticks(np.array([4,13,21]),("01-Aout","01-Sept","01-Oct"),fontsize=14)
pylab.savefig("S2_2B.png")
plt.show()

plt.plot(It_C[xJoursC],'o-',color="blue",linewidth=2.0)
plt.plot(I_C_pie[xJoursC],'o-',color="black",linewidth=1.0)
plt.ylim(ymax=6000)
plt.yticks(fontsize=14)
plt.xticks(np.array([4,13,21]),("01-Aout","01-Sept","01-Oct"),fontsize=14)
pylab.savefig("S2_2C.png")
plt.show()
