# %% [markdown]
# # Interprétation des données récoltées

# %% [markdown]
# Dans ce fichier, il y a les graphes des dynamiques des populations de larves, d'inflorescences vivantes et mortes pour des relevées journaliers ou deux fois par semaine. Ces données sont issues du fichier piege.
#
# Il y a aussi les graphes des températures (températures du sol).

# %% [markdown]
# ## Importation des librairies

# %%
import numpy as np
import csv
import matplotlib.pyplot as plt
from datetime import date, timedelta
from pandas import * # pour read_excel
import os
from Fonctions import *

# %% [markdown]
# ## Données piège

# %%
# On récupère les données du fichier piège ... 

os.chdir("../../Fichiers de donnees/Donnees re organisees/Fichier piege")

## SEMAINE

nb_larves_bloc1_s, nb_inflo_bloc1_s, nb_inflo_morte_bloc1_s = donnees("Bloc1_semaine", "date", "1", 'larves', 'inflos_vivantes', 'inflos_mortes')
nb_larves_bloc2_s, nb_inflo_bloc2_s, nb_inflo_morte_bloc2_s = donnees("Bloc2_semaine", "date", "1", 'larves', 'inflos_vivantes', 'inflos_mortes')
nb_larves_bloc1_bache_s, nb_inflo_bloc1_bache_s, nb_inflo_morte_bloc1_bache_s = donnees("Bloc1_bache_semaine", "date", "1", 'larves', 'inflos_vivantes', 'inflos_mortes')
nb_larves_bloc2_bache_s, nb_inflo_bloc2_bache_s, nb_inflo_morte_bloc2_bache_s = donnees("Bloc2_bache_semaine", "date", "1", 'larves', 'inflos_vivantes', 'inflos_mortes')
nb_larves_bloc1_enh_haut_s, nb_inflo_bloc1_enh_haut_s, nb_inflo_morte_bloc1_enh_haut_s = donnees("Bloc1_enh_haut_semaine", "date", "1", 'larves', 'inflos_vivantes', 'inflos_mortes')
nb_larves_bloc2_enh_haut_s, nb_inflo_bloc2_enh_haut_s, nb_inflo_morte_bloc2_enh_haut_s = donnees("Bloc2_enh_haut_semaine", "date", "1", 'larves', 'inflos_vivantes', 'inflos_mortes')
nb_larves_bloc1_enh_ras_s, nb_inflo_bloc1_enh_ras_s, nb_inflo_morte_bloc1_enh_ras_s = donnees("Bloc1_enh_ras_semaine", "date", "1", 'larves', 'inflos_vivantes', 'inflos_mortes')
nb_larves_bloc2_enh_ras_s, nb_inflo_bloc2_enh_ras_s, nb_inflo_morte_bloc2_enh_ras_s = donnees("Bloc2_enh_ras_semaine", "date", "1", 'larves', 'inflos_vivantes', 'inflos_mortes')

xJours_s = nb_larves_bloc1_s.index

## JOUR

nb_larves_bloc1_j, nb_inflo_bloc1_j, nb_inflo_morte_bloc1_j = donnees("Bloc1_jour", "date", "1", 'larves', 'inflos_vivantes', 'inflos_mortes')
nb_larves_bloc2_j, nb_inflo_bloc2_j, nb_inflo_morte_bloc2_j = donnees("Bloc2_jour", "date", "1", 'larves', 'inflos_vivantes', 'inflos_mortes')
nb_larves_bloc1_bache_j, nb_inflo_bloc1_bache_j, nb_inflo_morte_bloc1_bache_j = donnees("Bloc1_bache_jour", "date", "1", 'larves', 'inflos_vivantes', 'inflos_mortes')
nb_larves_bloc2_bache_j, nb_inflo_bloc2_bache_j, nb_inflo_morte_bloc2_bache_j = donnees("Bloc2_bache_jour", "date", "1", 'larves', 'inflos_vivantes', 'inflos_mortes')
nb_larves_bloc1_enh_haut_j, nb_inflo_bloc1_enh_haut_j, nb_inflo_morte_bloc1_enh_haut_j = donnees("Bloc1_enh_haut_jour", "date", "1", 'larves', 'inflos_vivantes', 'inflos_mortes')
nb_larves_bloc2_enh_haut_j, nb_inflo_bloc2_enh_haut_j, nb_inflo_morte_bloc2_enh_haut_j = donnees("Bloc2_enh_haut_jour", "date", "1", 'larves', 'inflos_vivantes', 'inflos_mortes')
nb_larves_bloc1_enh_ras_j, nb_inflo_bloc1_enh_ras_j, nb_inflo_morte_bloc1_enh_ras_j = donnees("Bloc1_enh_ras_jour", "date", "1", 'larves', 'inflos_vivantes', 'inflos_mortes')
nb_larves_bloc2_enh_ras_j, nb_inflo_bloc2_enh_ras_j, nb_inflo_morte_bloc2_enh_ras_j = donnees("Bloc2_enh_ras_jour", "date", "1", 'larves', 'inflos_vivantes', 'inflos_mortes')

xJours_j = nb_larves_bloc1_j.index

# %% [markdown]
# #### BLOC 1

# %%
# Jour

triplot (xJours_j, nb_larves_bloc1_bache_j, nb_larves_bloc1_enh_haut_j, nb_larves_bloc1_enh_ras_j, 
         "Bache", "Enh_haut", "Enh_ras", u"Nombre de larves piégées par jour")

triplot (xJours_j, nb_inflo_bloc1_bache_j, nb_inflo_bloc1_enh_haut_j, nb_inflo_bloc1_enh_ras_j, 
         "Bache", "Enh_haut", "Enh_ras", u"Nombre d'inflos vivantes par jour")

triplot (xJours_j, nb_inflo_morte_bloc1_bache_j, nb_inflo_morte_bloc1_enh_haut_j, nb_inflo_morte_bloc1_enh_ras_j,
         "Bache", "Enh_haut", "Enh_ras", u"Nombre d'inflos mortes par jour")

# %%
# Mardi et vendredi

triplot (xJours_s, nb_larves_bloc1_bache_s, nb_larves_bloc1_enh_haut_s, nb_larves_bloc1_enh_ras_s, 
         "Bache", "Enh_haut", "Enh_ras", u"Nombre de larves piégées (mardi et vendredi)")

triplot (xJours_s, nb_inflo_bloc1_bache_s, nb_inflo_bloc1_enh_haut_s, nb_inflo_bloc1_enh_ras_s, 
         "Bache", "Enh_haut", "Enh_ras", u"Nombre d'inflos vivantes (mardi et vendredi)")

triplot (xJours_s, nb_inflo_morte_bloc1_bache_s, nb_inflo_morte_bloc1_enh_haut_s, nb_inflo_morte_bloc1_enh_ras_s,
         "Bache", "Enh_haut", "Enh_ras", u"Nombre d'inflos mortes (mardi et vendredi)")

# %% [markdown]
# #### BLOC 2

# %%
# Jour

triplot (xJours_j, nb_larves_bloc2_bache_j, nb_larves_bloc2_enh_haut_j, nb_larves_bloc2_enh_ras_j, 
         "Bache", "Enh_haut", "Enh_ras", u"Nombre de larves piégées par jour")

triplot (xJours_j, nb_inflo_bloc2_bache_j, nb_inflo_bloc2_enh_haut_j, nb_inflo_bloc2_enh_ras_j, 
         "Bache", "Enh_haut", "Enh_ras", u"Nombre d'inflos vivantes par jour")

triplot (xJours_j, nb_inflo_morte_bloc2_bache_j, nb_inflo_morte_bloc2_enh_haut_j, nb_inflo_morte_bloc2_enh_ras_j,
         "Bache", "Enh_haut", "Enh_ras", u"Nombre d'inflos mortes par jour")

# %%
# Mardi et vendredi

triplot (xJours_s, nb_larves_bloc2_bache_s, nb_larves_bloc2_enh_haut_s, nb_larves_bloc2_enh_ras_s, 
         "Bache", "Enh_haut", "Enh_ras", u"Nombre de larves piégées (mardi et vendredi)")

triplot (xJours_s, nb_inflo_bloc2_bache_s, nb_inflo_bloc2_enh_haut_s, nb_inflo_bloc2_enh_ras_s, 
         "Bache", "Enh_haut", "Enh_ras", u"Nombre d'inflos vivantes (mardi et vendredi)")

triplot (xJours_s, nb_inflo_morte_bloc2_bache_s, nb_inflo_morte_bloc2_enh_haut_s, nb_inflo_morte_bloc2_enh_ras_s,
         "Bache", "Enh_haut", "Enh_ras", u"Nombre d'inflos mortes (mardi et vendredi)")

# %% [markdown]
# ## Discussion sur la cinétique des larves et des inflos
#
#
# ### BLOC1
#
#
# #### Larves piégées
#
# Bache : Il y a un pic de larves piégées autour du 20 septembre.
#
# Enh_haut : Il y a aussi un pic de larves piégées autour du 20 septembre mais ça augmente un peu avant.
#
# Enh_ras : A partir de mi-aout, le nombre de larves piégées augmente, la cinétique est en "dents de scie" jusqu'au pic du 20 septembre avec une diminution importante fin août.
#
#
# #### Inflos vivantes
#
# Bache : Le nombre d'inflorescences augmentent à partir de fin août et reste élevé jusqu'à fin septembre, puis commence à diminuer début octobre.
#
# Enh_haut : Cinétique similaire sauf commence à diminuer plus tôt (fin septembre), mais beaucoup plus d'inflos en général.
#
# Enh_ras : Cinétique très différente, le nombre d'inflorescences augmentent dès le début pour atteindre un pic à la mi-août, puis diminue rapidement, puis lentement jusqu'à la fin.
#
#
# #### Inflos mortes
#
# Bache : A partir de début août, le nombre d'inflos mortes augmente régulièrement, puis de façon exponentielle à partir de fin septembre.
#
# Enh_haut : Cinétique similaire, avec des dents de scie plus importantes.
#
# Enh_ras : Le nombre d'inflos mortes augmente brutalement à partir de fin août, puis reste élevé tout en faisant des dents de scie.
#
#
# #### INTERPRETATION
#
# Bache : Dans cette parcelle, le pic de floraison est de fin août à fin septembre. Le nombre de larves capturées avant est très faible à cause de la couverture du sol qui empêche les larves en diapause de l'année précédente d'émerger. Puis, il est très fort lors du pic de floraison et chute à cause de la diminution du nombre d'inflos vivantes (fin de floraison) et de l'augmentation du nombre d'inflos mortes (par les cécidomyies).
#
# Enh_haut : On peut faire les mêmes commentaires que précédemment, sauf le nombre de larves piégées qui augmente avant le pic dûe aux larves diapausantes émergeant.
#
# Enh_ras : Le pic de floraison est décalé par rapport aux parcelles précédentes, il est plus tôt, vers la mi-août, soit un mois plus tôt. Et donc le nombre d'inflos mortes augmente plus tôt aussi. On remarque que dès le début le nombre de larves piégées est plus important que dans les deux cas précédents, ce qui confirme l'idée que les larves diapausantes ont plus de facilité à émerger avec un sol nu.
#
#
# ### BLOC 2
#
#
# #### Larves piégées
#
# Bache : Le nombre de larves piégées augmente très rapidement pour atteindre un pic au 23 août et diminue brutalement.
#
# Enh_haut : Cinétique similaire mais augmente plus lentement au début.
#
# Enh_ras : Le nombre de larves piégées est très faible jusqu'à début septembre, puis augmente, avec deux pics et diminue.
#
#
# #### Inflos vivantes
#
# Bache : Le nombre d'inflorescences augmente dès le début. La période intense de floraison dure jusqu'à début septembre.
#
# Enh_haut : Cinétique similaire mais moins d'inflorescences.
#
# Enh_ras : Cinétique très différentes, pas d'inflos jusqu'à mi-août, puis augmente sensiblement avant le pic du 6 septembre, période de floraison très courte.
#
#
# #### Inflos mortes
#
# Bache : Le nombre d'inflos mortes augmente graduellement jusqu'au 20 août, puis diminue.
#
# Enh_haut : Le nombre d'inflos mortes augmente à partir de mi-août, puis reste en dents de scie.
#
# Enh_ras : Les inflos meurent seulement à partir du 6 septembre et de façon exponentielle. Elles sont beaucoup plus nombreuses que dans les parcelles précédentes.
#
#
# #### INTERPRETATION
#
# Bache : La période de floraison est au début, donc logiquement le nombre d'inflos est important, puis diminue après, à l'inverse du nombre d'inflos mortes et les larves piégées sont nombreuses au début et moindre à la fin.
#
# Enh_haut : Mêmes commentaires.
#
# Enh_ras : Mêmes commentaires avec période de floraison plus tardive.
#
# Pour l'enherbement ras, on remarque que le pic de larves piégées arrive en même temps que l'augmentation du nombre d'inflorescences et juste après le pic dans les deux autres sous parcelles. Le nombre d'inflorescences dans les deux autres sous parcelles diminue, celui des larves piégées aussi. On peut alors imaginer que les cécidomyies trouvant moins de disponibilité dans leur sous parcelle viennent ici. C'est aussi le moment où il y a un pic de baisse de température, les larves en diapause sortent plus avec des températures fraîches. Quelles hypothèses privilégier? Si on garde la première, on suppose qu'il y a échanges entre les sous-parcelles.
#
#
# ### POURQUOI PLUS DE LARVES CAPTUREES A LA FIN ALORS QU'IL Y A TOUJOURS DES INFLOS?
#
# On peut l'expliquer par l'augmentation des températures à la fin, qui augmente le temps de diapause d'après le papier de Paul. Les larves émergent "plus" avec des températures fraiches.
#
#
# ### TEMPERATURES RELEVEES
#
# D'après le raport de Lucie, il y a trois périodes distinctes :
# - De début juillet à début août, les températures sont constantes avec une faible amplitude journalière.
# - De début août à début octobre, les températures sont constantes avec une plus grande amplitude journalière.
# - De début octobre à fin novembre : augmentation nette des températures.

# %%
# On récupère les données des fichiers températures ... 

os.chdir("../../Donnees brutes/Temperature")

# ... Et on les met dans des variables

tMin_bloc2_bache, tMax_bloc2_bache, tMoy_bloc2_bache = donnees ("TT1_PS_Bloc2", 'Date', 'TT1_PS_Bloc2', "Tmin", "Tmax", "Tmoy")
tMin_bloc2_enh_haut, tMax_bloc2_enh_haut, tMoy_bloc2_enh_haut = donnees ("TT2_EH_Bloc2", 'Date', 'TT2_EH_Bloc2', "Tmin", "Tmax", "Tmoy")
tMin_bloc2_enh_ras, tMax_bloc2_enh_ras, tMoy_bloc2_enh_ras = donnees ("TT3_ER_Bloc2", 'Date', 'TT3_ER_Bloc2', "Tmin", "Tmax", "Tmoy")
tMin_bloc1_enh_haut, tMax_bloc1_enh_haut, tMoy_bloc1_enh_haut = donnees ("TT4_EH_Bloc1", 'Date', 'TT4_EH_Bloc1', "Tmin", "Tmax", "Tmoy")
tMin_bloc1_enh_ras, tMax_bloc1_enh_ras, tMoy_bloc1_enh_ras = donnees ("TT5_ER_Bloc1", 'Date', 'TT5_ER_Bloc1', "Tmin", "Tmax", "Tmoy")
tMin_bloc1_bache, tMax_bloc1_bache, tMoy_bloc1_bache = donnees ("TT6_PS_Bloc1", 'Date', 'TT6_PS_Bloc1', "Tmin", "Tmax", "Tmoy")

d1 = tMin_bloc2_bache.index
d2 = tMin_bloc2_enh_haut.index
d3 = tMin_bloc2_enh_ras.index
d4 = tMin_bloc1_bache.index
d5 = tMin_bloc1_enh_haut.index
d6 = tMin_bloc1_enh_ras.index

# %%
triplot (d1, tMax_bloc2_bache, tMoy_bloc2_bache, tMin_bloc2_bache, "Tmax", "Tmoy", "Tmin", "Bloc2 _ Bache")
triplot (d2, tMax_bloc2_enh_haut, tMoy_bloc2_enh_haut, tMin_bloc2_enh_haut, "Tmax", "Tmoy", "Tmin", "Bloc2 _ Enherbement haut")
triplot (d3, tMax_bloc2_enh_ras, tMoy_bloc2_enh_ras, tMin_bloc2_enh_ras, "Tmax", "Tmoy", "Tmin", "Bloc2 _ Enherbement ras")
triplot (d4, tMax_bloc1_enh_haut, tMoy_bloc1_enh_haut, tMin_bloc1_enh_haut, "Tmax", "Tmoy", "Tmin", "Bloc1 _ Enherbement haut")
triplot (d5, tMax_bloc1_enh_ras, tMoy_bloc1_enh_ras, tMin_bloc1_enh_ras, "Tmax", "Tmoy", "Tmin", "Bloc1 _ Enherbement ras")
triplot (d6, tMax_bloc1_bache, tMoy_bloc1_bache, tMin_bloc2_bache, "Tmax", "Tmoy", "Tmin", "Bloc1 _ Bache")

# %%
trisubplot(d1, tMax_bloc2_bache, tMoy_bloc2_bache, tMin_bloc2_bache, "Tmax", "Tmoy", "Tmin", "Bloc2 _ Bache", 
           xJours_s, nb_larves_bloc2_bache_s, u"Larves piégées", xJours_s, nb_inflo_bloc2_bache_s, "Inflos")

trisubplot(d2, tMax_bloc2_enh_haut, tMoy_bloc2_enh_haut, tMin_bloc2_enh_haut, "Tmax", "Tmoy", "Tmin", "Bloc2 _ Enherbement haut",
           xJours_s, nb_larves_bloc2_enh_haut_s, u"Larves piégées", xJours_s, nb_inflo_bloc2_enh_haut_s, "Inflos")

trisubplot(d3, tMax_bloc2_enh_ras, tMoy_bloc2_enh_ras, tMin_bloc2_enh_ras, "Tmax", "Tmoy", "Tmin", "Bloc2 _ Enherbement ras",
           xJours_s, nb_larves_bloc2_enh_ras_s, u"Larves piégées", xJours_s, nb_inflo_bloc2_enh_ras_s, "Inflos")

trisubplot(d4, tMax_bloc1_enh_haut, tMoy_bloc1_enh_haut, tMin_bloc1_enh_haut, "Tmax", "Tmoy", "Tmin", "Bloc1 _ Enherbement haut",
           xJours_s, nb_larves_bloc1_enh_haut_s, u"Larves piégées", xJours_s, nb_inflo_bloc1_enh_haut_s, "Inflos")

trisubplot(d5, tMax_bloc1_enh_ras, tMoy_bloc1_enh_ras, tMin_bloc1_enh_ras, "Tmax", "Tmoy", "Tmin", "Bloc1 _ Enherbement ras",
           xJours_s, nb_larves_bloc1_enh_ras_s, u"Larves piégées", xJours_s, nb_inflo_bloc1_enh_ras_s, "Inflos")

trisubplot(d6, tMax_bloc1_bache, tMoy_bloc1_bache, tMin_bloc2_bache, "Tmax", "Tmoy", "Tmin", "Bloc1 _ Bache",
           xJours_s, nb_larves_bloc1_bache_s, u"Larves piégées", xJours_s, nb_inflo_bloc1_bache_s, "Inflos")

# %%
deuxsubplot (xJours_j, nb_larves_bloc1_bache_j + nb_larves_bloc1_enh_haut_j + nb_larves_bloc1_enh_ras_j, nb_inflo_bloc1_bache_j + nb_inflo_bloc1_enh_haut_j + nb_inflo_bloc1_enh_ras_j, (nb_inflo_bloc1_bache_j + nb_inflo_bloc1_enh_haut_j + nb_inflo_bloc1_enh_ras_j) - (nb_larves_bloc1_bache_j + nb_larves_bloc1_enh_haut_j + nb_larves_bloc1_enh_ras_j), 
             "Larves", "Inflos", "Inflos-Larves", "Bloc1")

deuxsubplot (xJours_j, nb_larves_bloc1_bache_j, nb_inflo_bloc1_bache_j, nb_inflo_bloc1_bache_j - nb_larves_bloc1_bache_j, 
             "Larves", "Inflos", "Inflos-Larves", "Bloc1 _ Bache")

deuxsubplot (xJours_j, nb_larves_bloc1_enh_haut_j, nb_inflo_bloc1_enh_haut_j, nb_inflo_bloc1_enh_haut_j - nb_larves_bloc1_enh_haut_j,
             "Larves", "Inflos", "Inflos-Larves", "Bloc1 _ Enherbement haut")

deuxsubplot (xJours_j, nb_larves_bloc1_enh_ras_j, nb_inflo_bloc1_enh_ras_j, nb_inflo_bloc1_enh_ras_j - nb_larves_bloc1_enh_ras_j,
             "Larves", "Inflos", "Inflos-Larves", "Bloc1 _ Enherbement ras")

deuxsubplot (xJours_j, nb_larves_bloc2_bache_j, nb_inflo_bloc2_bache_j, nb_inflo_bloc2_bache_j - nb_larves_bloc2_bache_j,
             "Larves", "Inflos", "Inflos-Larves", "Bloc2 _ Bache")

deuxsubplot (xJours_j, nb_larves_bloc2_enh_haut_j, nb_inflo_bloc2_enh_haut_j, nb_inflo_bloc2_enh_haut_j - nb_larves_bloc2_enh_haut_j,
             "Larves", "Inflos", "Inflos-Larves", "Bloc2 _ Enherbement haut")

deuxsubplot (xJours_j, nb_larves_bloc2_enh_ras_j, nb_inflo_bloc2_enh_ras_j, nb_inflo_bloc2_enh_ras_j - nb_larves_bloc2_enh_ras_j,
             "Larves", "Inflos", "Inflos-Larves", "Bloc2 _ Enherbement ras")

# %%
deuxsubplot (xJours_s, nb_larves_bloc1_bache_s, nb_inflo_bloc1_bache_s, nb_inflo_bloc1_bache_s - nb_larves_bloc1_bache_s, 
             "Larves", "Inflos", "Inflos-Larves", "Bloc1 _ Bache")

deuxsubplot (xJours_s, nb_larves_bloc1_enh_haut_s, nb_inflo_bloc1_enh_haut_s, nb_inflo_bloc1_enh_haut_s - nb_larves_bloc1_enh_haut_s,
             "Larves", "Inflos", "Inflos-Larves", "Bloc1 _ Enherbement haut")

deuxsubplot (xJours_s, nb_larves_bloc1_enh_ras_s, nb_inflo_bloc1_enh_ras_s, nb_inflo_bloc1_enh_ras_s - nb_larves_bloc1_enh_ras_s,
             "Larves", "Inflos", "Inflos-Larves", "Bloc1 _ Enherbement ras")

deuxsubplot (xJours_s, nb_larves_bloc2_bache_s, nb_inflo_bloc2_bache_s, nb_inflo_bloc2_bache_s - nb_larves_bloc2_bache_s,
             "Larves", "Inflos", "Inflos-Larves", "Bloc2 _ Bache")

deuxsubplot (xJours_s, nb_larves_bloc2_enh_haut_s, nb_inflo_bloc2_enh_haut_s, nb_inflo_bloc2_enh_haut_s - nb_larves_bloc2_enh_haut_s,
             "Larves", "Inflos", "Inflos-Larves", "Bloc2 _ Enherbement haut")

deuxsubplot (xJours_s, nb_larves_bloc2_enh_ras_s, nb_inflo_bloc2_enh_ras_s, nb_inflo_bloc2_enh_ras_s - nb_larves_bloc2_enh_ras_s,
             "Larves", "Inflos", "Inflos-Larves", "Bloc2 _ Enherbement ras")

# %%
deuxsubplot (xJours_s, nb_inflo_bloc1_bache_s + nb_inflo_bloc1_enh_haut_s + nb_inflo_bloc1_enh_ras_s, nb_inflo_morte_bloc1_bache_s + nb_inflo_morte_bloc1_bache_s + nb_inflo_morte_bloc1_enh_ras_s, (nb_inflo_bloc1_bache_s + nb_inflo_bloc1_enh_haut_s + nb_inflo_bloc1_enh_ras_s) - (nb_inflo_morte_bloc1_bache_s + nb_inflo_morte_bloc1_bache_s + nb_inflo_morte_bloc1_enh_ras_s), 
             "Inflos vivantes", "Inflos mortes", "Vivantes-Mortes", "Bloc1")

deuxsubplot (xJours_s, nb_inflo_bloc1_bache_s, nb_inflo_morte_bloc1_bache_s, nb_inflo_bloc1_bache_s - nb_inflo_morte_bloc1_bache_s, 
             "Inflos vivantes", "Inflos mortes", "Vivantes-Mortes", "Bloc1 bache")

deuxsubplot (xJours_s, nb_inflo_bloc1_enh_haut_s, nb_inflo_morte_bloc1_enh_haut_s, nb_inflo_bloc1_enh_haut_s - nb_inflo_morte_bloc1_enh_haut_s, 
             "Inflos vivantes", "Inflos mortes", "Vivantes-Mortes", "Bloc1 enh_haut")

deuxsubplot (xJours_s, nb_inflo_bloc1_enh_ras_s, nb_inflo_morte_bloc1_enh_ras_s, nb_inflo_bloc1_enh_ras_s - nb_inflo_morte_bloc1_enh_ras_s, 
             "Inflos vivantes", "Inflos mortes", "Vivantes-Mortes", "Bloc1 enh_ras")

# %%
deuxsubplot (xJours_s, nb_inflo_bloc2_bache_s + nb_inflo_bloc2_enh_haut_s + nb_inflo_bloc2_enh_ras_s, nb_inflo_morte_bloc2_bache_s + nb_inflo_morte_bloc2_bache_s + nb_inflo_morte_bloc2_enh_ras_s, (nb_inflo_bloc2_bache_s + nb_inflo_bloc2_enh_haut_s + nb_inflo_bloc2_enh_ras_s) - (nb_inflo_morte_bloc2_bache_s + nb_inflo_morte_bloc2_bache_s + nb_inflo_morte_bloc2_enh_ras_s), 
             "Inflos vivantes", "Inflos mortes", "Vivantes-Mortes", "Bloc2")

deuxsubplot (xJours_s, nb_inflo_bloc1_bache_s, nb_inflo_morte_bloc2_bache_s, nb_inflo_bloc2_bache_s - nb_inflo_morte_bloc2_bache_s, 
             "Inflos vivantes", "Inflos mortes", "Vivantes-Mortes", "Bloc2 bache")

deuxsubplot (xJours_s, nb_inflo_bloc2_enh_haut_s, nb_inflo_morte_bloc2_enh_haut_s, nb_inflo_bloc2_enh_haut_s - nb_inflo_morte_bloc2_enh_haut_s, 
             "Inflos vivantes", "Inflos mortes", "Vivantes-Mortes", "Bloc2 enh_haut")

deuxsubplot (xJours_s, nb_inflo_bloc2_enh_ras_s, nb_inflo_morte_bloc2_enh_ras_s, nb_inflo_bloc2_enh_ras_s - nb_inflo_morte_bloc2_enh_ras_s, 
             "Inflos vivantes", "Inflos mortes", "Vivantes-Mortes", "Bloc2 enh_ras")
