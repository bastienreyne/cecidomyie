# %% [markdown]
# # OPTIMISATION
#
# Dans les scripts, comme dans le poster, on note :
# * A $\Leftrightarrow$ Enherbement Bas
# * B $\Leftrightarrow$ Bachage
# * C $\Leftrightarrow$ Enherbement Haut
#
# Population de cecido exogene en fonction du nombre d'inflorescences

# %%
import os 
import numpy as np
import matplotlib.pyplot as plt

os.chdir("/home/laurie/Dropbox/Cecidomyie/Python")

from Datas import *
import FunModele as mdl
import FunOptimisation as opt
import FunObj as obj
from Bounds import *

# %%
# Parametres conserves pour l'initiatlisation 
## Lambda, fonction des inflorescences
## Dispersion en fonction de la proportion d'inflorescences

lambda_  = 0.7
mu_MS_A  = 0.4
mu_MS_C  = 0.6
pl       = 0.30
k        = 0.63
params = [lambda_,mu_MS_A,mu_MS_C,pl,k]
args = [TotJours,I_A,I_B,I_C,d_l,E,mu,p_pup,d_p,beta,mdl.popExo2,mdl.out2]
bounds = ([0,0,0,0,0],[20,1,1,1,np.inf])

# %%
## Fonction objectif = MAE

# Pas de normalisation
res_1, Lt_A_1, Lt_p_A_1, Nt_A_1, Lt_B_1, Lt_p_B_1, Nt_B_1, Lt_C_1, Lt_p_C_1, Nt_C_1 = opt.visual_opt_bis0(params,args,obj.MAE,L_A,L_B,L_C,mybounds1)

# Normalisation 1
res_2, Lt_A_2, Lt_p_A_2, Nt_A_2, Lt_B_2, Lt_p_B_2, Nt_B_2, Lt_C_2, Lt_p_C_2, Nt_C_2 = opt.visual_opt_bis0(params,args,obj.MAE_1,L_A,L_B,L_C,mybounds1)

# Normalisation 2
res_3, Lt_A_3, Lt_p_A_3, Nt_A_3, Lt_B_3, Lt_p_B_3, Nt_B_3, Lt_C_3, Lt_p_C_3, Nt_C_3 = opt.visual_opt_bis0(params,args,obj.MAE_2,L_A,L_B,L_C,mybounds1)

# Normalisation 3
res_4, Lt_A_4, Lt_p_A_4, Nt_A_4, Lt_B_4, Lt_p_B_4, Nt_B_4, Lt_C_4, Lt_p_C_4, Nt_C_4 = opt.visual_opt_bis0(params,args,obj.MAE_3,L_A,L_B,L_C,mybounds1)

# %%
## Fonction objectif = MSE

# Pas de normalisation
res_5, Lt_A_5, Lt_p_A_5, Nt_A_5, Lt_B_5, Lt_p_B_5, Nt_B_5, Lt_C_5, Lt_p_C_5, Nt_C_5 = opt.visual_opt_bis0(params,args,obj.MSE,L_A,L_B,L_C,mybounds1)

# Normalisation 1
res_6, Lt_A_6, Lt_p_A_6, Nt_A_6, Lt_B_6, Lt_p_B_6, Nt_B_6, Lt_C_6, Lt_p_C_6, Nt_C_6 = opt.visual_opt_bis0(params,args,obj.MSE_1,L_A,L_B,L_C,mybounds1)

# Normalisation 2
res_7, Lt_A_7, Lt_p_A_7, Nt_A_7, Lt_B_7, Lt_p_B_7, Nt_B_7, Lt_C_7, Lt_p_C_7, Nt_C_7 = opt.visual_opt_bis0(params,args,obj.MSE_2,L_A,L_B,L_C,mybounds1)

# Normalisation 3
res_8, Lt_A_8, Lt_p_A_8, Nt_A_8, Lt_B_8, Lt_p_B_8, Nt_B_8, Lt_C_8, Lt_p_C_8, Nt_C_8 = opt.visual_opt_bis0(params,args,obj.MSE_3,L_A,L_B,L_C,mybounds1)

# %%
## Fonction objectif = RMSE

# Pas de normalisation
res_9, Lt_A_9, Lt_p_A_9, Nt_A_9, Lt_B_9, Lt_p_B_9, Nt_B_9, Lt_C_9, Lt_p_C_9, Nt_C_9 = opt.visual_opt_bis0(params,args,obj.RMSE,L_A,L_B,L_C,mybounds1)

# Normalisation 1
res_10, Lt_A_10, Lt_p_A_10, Nt_A_10, Lt_B_10, Lt_p_B_10, Nt_B_10, Lt_C_10, Lt_p_C_10, Nt_C_10 = opt.visual_opt_bis0(params,args,obj.RMSE_1,L_A,L_B,L_C,mybounds1)

# Normalisation 2
res_11, Lt_A_11, Lt_p_A_11, Nt_A_11, Lt_B_11, Lt_p_B_11, Nt_B_11, Lt_C_11, Lt_p_C_11, Nt_C_11 = opt.visual_opt_bis0(params,args,obj.RMSE_2,L_A,L_B,L_C,mybounds1)

# Normalisation 3
res_12, Lt_A_12, Lt_p_A_12, Nt_A_12, Lt_B_12, Lt_p_B_12, Nt_B_12, Lt_C_12, Lt_p_C_12, Nt_C_12 = opt.visual_opt_bis0(params,args,obj.RMSE_3,L_A,L_B,L_C,mybounds1)

# %%
## Fonction objectif = RRMSE

res_13, Lt_A_13, Lt_p_A_13, Nt_A_13, Lt_B_13, Lt_p_B_13, Nt_B_13, Lt_C_13, Lt_p_C_13, Nt_C_13 = opt.visual_opt_bis0(params,args,obj.RRMSE,L_A,L_B,L_C,mybounds1)

# %%
## Fonction objectif = PCC

res_14, Lt_A_14, Lt_p_A_14, Nt_A_14, Lt_B_14, Lt_p_B_14, Nt_B_14, Lt_C_14, Lt_p_C_14, Nt_C_14 = opt.visual_opt_bis0(params,args,obj.PCC,L_A,L_B,L_C,mybounds1)

# %%
## Fonction objectif = D

res_15, Lt_A_15, Lt_p_A_15, Nt_A_15, Lt_B_15, Lt_p_B_15, Nt_B_15, Lt_C_15, Lt_p_C_15, Nt_C_15 = opt.visual_opt_bis0(params,args,obj.D,L_A,L_B,L_C,mybounds1)

# %%
## Fonction objectif = NSE

res_16, Lt_A_16, Lt_p_A_16, Nt_A_16, Lt_B_16, Lt_p_B_16, Nt_B_16, Lt_C_16, Lt_p_C_16, Nt_C_16 = opt.visual_opt_bis0(params,args,obj.NSE,L_A,L_B,L_C,mybounds1)

# %%
print (res_2.x)
print (res_3.x)
print (res_5.x)
print (res_6.x)
print (res_10.x)
print (res_11.x)
print (res_14.x)
print (res_15.x)
# Out:
# [0.92587415 0.91433043 0.09793671 0.6189932  0.06727753]
# [0.8530961  0.40298982 0.63316262 0.21720383 0.31963716]
# [1.21455972 0.52214343 0.26569563 0.28668346 0.40659246]
# [0.78385245 0.39164901 0.61463318 0.23781997 0.53683061]
# [0.78197148 0.3991301  0.61556947 0.24675398 0.53892058]
# [0.79523442 0.41013893 0.60820499 0.27909345 0.5442297 ]
# [0.77214305 0.86064624 0.33235945 0.51519396 0.17812523]
# [0.81405737 0.60049594 0.14880195 0.4659208  0.08770415]

# %%
P = np.array([res_14.x,res_15.x])
print (P[:,0])
print (np.mean(P[:,0]))
print (P[:,1])
print (np.mean(P[:,1]))
print (P[:,2])
print (np.mean(P[:,2]))
print (P[:,3])
print (np.mean(P[:,3]))
print (P[:,4])
print (np.mean(P[:,4]))
# Out:
# [0.77214305 0.81405737]
# 0.7931002104127864
# [0.86064624 0.60049594]
# 0.7305710895181877
# [0.33235945 0.14880195]
# 0.24058070108002488
# [0.51519396 0.4659208 ]
# 0.49055738212025624
# [0.17812523 0.08770415]
# 0.13291468892195668
