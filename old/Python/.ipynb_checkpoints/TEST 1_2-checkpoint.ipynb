# %% [markdown]
# # OPTIMISATION
#
# Dans les scripts, comme dans le poster, on note :
# * A $\Leftrightarrow$ Enherbement Bas
# * B $\Leftrightarrow$ Bachage
# * C $\Leftrightarrow$ Enherbement Haut
#
# Population de cecido exogene en fonction du nombre d'inflorescences

# %%
import os 
import numpy as np
import matplotlib.pyplot as plt

os.chdir("C:/Users/Laurie/Dropbox/Cecidomyie/Python")

from Datas import *
import FunModele as mdl
import FunOptimisation as opt
import FunObj as obj

# %%
# Parametres conserves pour l'initiatlisation 
## Lambda, fonction des inflorescences
## Dispersion en fonction de la proportion d'inflorescences

lambda_A = 1.00
lambda_B = 0.29
lambda_C = 0.20
mu_MS_A  = 0.41
mu_MS_C  = 0.02
pl       = 0.30
k        = 0.63
params = [lambda_A,lambda_B,lambda_C,mu_MS_A,mu_MS_C,pl,k]
args = [TotJours,I_A,I_B,I_C,d_l,E,mu,p_pup,d_p,beta,mdl.popExo2,mdl.out2]
bounds = ([0,0,0,0,0,0,0],[20,20,20,1,1,1,np.inf])

# %%
res_1, Lt_A_1, Lt_p_A_1, Nt_A_1, Lt_B_1, Lt_p_B_1, Nt_B_1, Lt_C_1, Lt_p_C_1, Nt_C_1 = opt.visual_opt_bis0(params,args,obj.MAE,L_A,L_B,L_C)

# %%
## Fonction objectif = MAE

# Pas de normalisation
res_1, Lt_A_1, Lt_p_A_1, Nt_A_1, Lt_B_1, Lt_p_B_1, Nt_B_1, Lt_C_1, Lt_p_C_1, Nt_C_1 = opt.visual_opt_bis0(params,args,obj.MAE,L_A,L_B,L_C)

# Normalisation 1
res_2, Lt_A_2, Lt_p_A_2, Nt_A_2, Lt_B_2, Lt_p_B_2, Nt_B_2, Lt_C_2, Lt_p_C_2, Nt_C_2 = opt.visual_opt_bis0(params,args,obj.MAE_1,L_A,L_B,L_C)

# Normalisation 2
res_3, Lt_A_3, Lt_p_A_3, Nt_A_3, Lt_B_3, Lt_p_B_3, Nt_B_3, Lt_C_3, Lt_p_C_3, Nt_C_3 = opt.visual_opt_bis0(params,args,obj.MAE_2,L_A,L_B,L_C)

# Normalisation 3
res_4, Lt_A_4, Lt_p_A_4, Nt_A_4, Lt_B_4, Lt_p_B_4, Nt_B_4, Lt_C_4, Lt_p_C_4, Nt_C_4 = opt.visual_opt_bis0(params,args,obj.MAE_3,L_A,L_B,L_C)

# %%
## Fonction objectif = MSE

# Pas de normalisation
res_5, Lt_A_5, Lt_p_A_5, Nt_A_5, Lt_B_5, Lt_p_B_5, Nt_B_5, Lt_C_5, Lt_p_C_5, Nt_C_5 = opt.visual_opt_bis0(params,args,obj.MSE,L_A,L_B,L_C)

# Normalisation 1
res_6, Lt_A_6, Lt_p_A_6, Nt_A_6, Lt_B_6, Lt_p_B_6, Nt_B_6, Lt_C_6, Lt_p_C_6, Nt_C_6 = opt.visual_opt_bis0(params,args,obj.MSE_1,L_A,L_B,L_C)

# Normalisation 2
res_7, Lt_A_7, Lt_p_A_7, Nt_A_7, Lt_B_7, Lt_p_B_7, Nt_B_7, Lt_C_7, Lt_p_C_7, Nt_C_7 = opt.visual_opt_bis0(params,args,obj.MSE_2,L_A,L_B,L_C)

# Normalisation 3
res_8, Lt_A_8, Lt_p_A_8, Nt_A_8, Lt_B_8, Lt_p_B_8, Nt_B_8, Lt_C_8, Lt_p_C_8, Nt_C_8 = opt.visual_opt_bis0(params,args,obj.MSE_3,L_A,L_B,L_C)
# Out:
# C:\Users\Laurie\Anaconda2\lib\site-packages\scipy\optimize\optimize.py:1013: RuntimeWarning: divide by zero encountered in double_scalars
#   rhok = 1.0 / (numpy.dot(yk, sk))

# %%
## Fonction objectif = RMSE

# Pas de normalisation
res_9, Lt_A_9, Lt_p_A_9, Nt_A_9, Lt_B_9, Lt_p_B_9, Nt_B_9, Lt_C_9, Lt_p_C_9, Nt_C_9 = opt.visual_opt_bis0(params,args,obj.RMSE,L_A,L_B,L_C)

# Normalisation 1
res_10, Lt_A_10, Lt_p_A_10, Nt_A_10, Lt_B_10, Lt_p_B_10, Nt_B_10, Lt_C_10, Lt_p_C_10, Nt_C_10 = opt.visual_opt_bis0(params,args,obj.RMSE_1,L_A,L_B,L_C)

# Normalisation 2
res_11, Lt_A_11, Lt_p_A_11, Nt_A_11, Lt_B_11, Lt_p_B_11, Nt_B_11, Lt_C_11, Lt_p_C_11, Nt_C_11 = opt.visual_opt_bis0(params,args,obj.RMSE_2,L_A,L_B,L_C)

# Normalisation 3
res_12, Lt_A_12, Lt_p_A_12, Nt_A_12, Lt_B_12, Lt_p_B_12, Nt_B_12, Lt_C_12, Lt_p_C_12, Nt_C_12 = opt.visual_opt_bis0(params,args,obj.RMSE_3,L_A,L_B,L_C)

# %%
## Fonction objectif = RRMSE

res_13, Lt_A_13, Lt_p_A_13, Nt_A_13, Lt_B_13, Lt_p_B_13, Nt_B_13, Lt_C_13, Lt_p_C_13, Nt_C_13 = opt.visual_opt_bis0(params,args,obj.RRMSE,L_A,L_B,L_C)

# %%
## Fonction objectif = PCC

res_14, Lt_A_14, Lt_p_A_14, Nt_A_14, Lt_B_14, Lt_p_B_14, Nt_B_14, Lt_C_14, Lt_p_C_14, Nt_C_14 = opt.visual_opt_bis0(params,args,obj.PCC,L_A,L_B,L_C)

# %%
## Fonction objectif = D

res_15, Lt_A_15, Lt_p_A_15, Nt_A_15, Lt_B_15, Lt_p_B_15, Nt_B_15, Lt_C_15, Lt_p_C_15, Nt_C_15 = opt.visual_opt_bis0(params,args,obj.D,L_A,L_B,L_C)

# %%
## Fonction objectif = NSE

res_16, Lt_A_16, Lt_p_A_16, Nt_A_16, Lt_B_16, Lt_p_B_16, Nt_B_16, Lt_C_16, Lt_p_C_16, Nt_C_16 = opt.visual_opt_bis0(params,args,obj.NSE,L_A,L_B,L_C)

# %%
print (res_1.x)
print (res_2.x)
print (res_3.x)
print (res_4.x)
print (res_5.x)
print (res_6.x)
print (res_7.x)
print (res_8.x)
print (res_9.x)
print (res_10.x)
print (res_11.x)
print (res_12.x)
print (res_13.x)
print (res_14.x)
print (res_15.x)
print (res_16.x)
# Out:
# [ 3.22863916  0.39917675  0.54044602  0.626576   -0.64361849  0.74627722
#   0.47065617]
# [ 3.52408917 -0.11588111  0.64488954  0.29557644  2.31384452  0.47421265
#   0.0831699 ]
# [ 2.36122365 17.1808172   2.45216348  1.32974832 -4.21978827 -3.25680825
#   0.25139718]
# [1.         0.40580062 0.33959616 0.42579726 0.20415435 0.27818609
#  0.69867967]
# [ 0.34808439  0.64224796  0.56678913  0.52775979 -0.71071842  0.65954662
#   0.51903158]
# [ 4.97635248e-01 -1.99265705e-04  4.58204075e-01 -1.00372444e-01
#  -2.82373802e-01  1.15700871e+00  8.14672012e-02]
# [ 2.40700068e+03 -6.24919137e+02  4.67267017e+04 -1.91111989e-02
#  -9.54993652e-01  1.36464803e+04  1.75831466e+00]
# [1.45928397 0.14608305 0.42242053 0.07888685 0.46615878 0.09617072
#  1.26036567]
# [ 0.39555184  0.64784987  0.5425289   0.48056371 -0.78188865  0.62543478
#   0.34941834]
# [1.80787201 3.74143358 0.45209348 1.45748273 0.73647282 2.65285236
#  0.04504191]
# ...
