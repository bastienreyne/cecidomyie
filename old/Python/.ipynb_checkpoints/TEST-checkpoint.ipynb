# %% [markdown]
# # OPTIMISATION
#
# Dans les scripts, comme dans le poster, on note :
# * A $\Leftrightarrow$ Enherbement Bas
# * B $\Leftrightarrow$ Bachage
# * C $\Leftrightarrow$ Enherbement Haut
#
# Population de cecido exogene en fonction du nombre d'inflorescences

# %%
import os 
import numpy as np
import matplotlib.pyplot as plt

os.chdir("C:/Users/Laurie/Dropbox/Cecidomyie/Python")

from Datas import *
import FunModele as mdl
import FunOptimisation as opt
import FunObj as obj

# %%
# Parametres conserves pour l'initiatlisation 
## Lambda, fonction des inflorescences
## Dispersion en fonction de la proportion d'inflorescences

lambda_A = 0.7
lambda_B = 0.95
lambda_C = 0.63
mu_MS_A  = 0.55
mu_MS_C  = 0.83
pl       = 0.73
k        = 0.06

params = [lambda_A,lambda_B,lambda_C,mu_MS_A,mu_MS_C,pl,k]
args = [TotJours,I_A,I_B,I_C,d_l,E,mu,p_pup,d_p,beta,mdl.popExo2,mdl.out2]
bounds = ([0,0,0,0,0,0,0],[20,1,1,1,np.inf])

# %%
## Fonction objectif = MAE

# Pas de normalisation
res_1, Lt_A_1, Lt_p_A_1, Nt_A_1, Lt_B_1, Lt_p_B_1, Nt_B_1, Lt_C_1, Lt_p_C_1, Nt_C_1 = opt.visual_opt(params,args,obj.MAE,L_A,L_B,L_C,bounds)

# Normalisation 1
res_2, Lt_A_2, Lt_p_A_2, Nt_A_2, Lt_B_2, Lt_p_B_2, Nt_B_2, Lt_C_2, Lt_p_C_2, Nt_C_2 = opt.visual_opt(params,args,obj.MAE_1,L_A,L_B,L_C,bounds)

# Normalisation 2
res_3, Lt_A_3, Lt_p_A_3, Nt_A_3, Lt_B_3, Lt_p_B_3, Nt_B_3, Lt_C_3, Lt_p_C_3, Nt_C_3 = opt.visual_opt(params,args,obj.MAE_2,L_A,L_B,L_C,bounds)

# %%
## Fonction objectif = MSE

# Pas de normalisation
res_5, Lt_A_5, Lt_p_A_5, Nt_A_5, Lt_B_5, Lt_p_B_5, Nt_B_5, Lt_C_5, Lt_p_C_5, Nt_C_5 = opt.visual_opt(params,args,obj.MSE,L_A,L_B,L_C,bounds)

# Normalisation 1
res_6, Lt_A_6, Lt_p_A_6, Nt_A_6, Lt_B_6, Lt_p_B_6, Nt_B_6, Lt_C_6, Lt_p_C_6, Nt_C_6 = opt.visual_opt(params,args,obj.MSE_1,L_A,L_B,L_C,bounds)

# Normalisation 2
res_7, Lt_A_7, Lt_p_A_7, Nt_A_7, Lt_B_7, Lt_p_B_7, Nt_B_7, Lt_C_7, Lt_p_C_7, Nt_C_7 = opt.visual_opt(params,args,obj.MSE_2,L_A,L_B,L_C,bounds)

# %%
## Fonction objectif = RMSE

# Pas de normalisation
res_9, Lt_A_9, Lt_p_A_9, Nt_A_9, Lt_B_9, Lt_p_B_9, Nt_B_9, Lt_C_9, Lt_p_C_9, Nt_C_9 = opt.visual_opt(params,args,obj.RMSE,L_A,L_B,L_C,bounds)

# Normalisation 1
res_10, Lt_A_10, Lt_p_A_10, Nt_A_10, Lt_B_10, Lt_p_B_10, Nt_B_10, Lt_C_10, Lt_p_C_10, Nt_C_10 = opt.visual_opt(params,args,obj.RMSE_1,L_A,L_B,L_C,bounds)

# Normalisation 2
res_11, Lt_A_11, Lt_p_A_11, Nt_A_11, Lt_B_11, Lt_p_B_11, Nt_B_11, Lt_C_11, Lt_p_C_11, Nt_C_11 = opt.visual_opt(params,args,obj.RMSE_2,L_A,L_B,L_C,bounds)

# %%
## Fonction objectif = RRMSE

res_13, Lt_A_13, Lt_p_A_13, Nt_A_13, Lt_B_13, Lt_p_B_13, Nt_B_13, Lt_C_13, Lt_p_C_13, Nt_C_13 = opt.visual_opt(params,args,obj.RRMSE,L_A,L_B,L_C,bounds)

# %%
## Fonction objectif = D

res_15, Lt_A_15, Lt_p_A_15, Nt_A_15, Lt_B_15, Lt_p_B_15, Nt_B_15, Lt_C_15, Lt_p_C_15, Nt_C_15 = opt.visual_opt(params,args,obj.D,L_A,L_B,L_C,bounds)

# %%
## Fonction objectif = NSE

res_16, Lt_A_16, Lt_p_A_16, Nt_A_16, Lt_B_16, Lt_p_B_16, Nt_B_16, Lt_C_16, Lt_p_C_16, Nt_C_16 = opt.visual_opt(params,args,obj.NSE,L_A,L_B,L_C,bounds)

# %%
P = np.array([res_1.x,res_2.x,res_3.x,res_5.x,res_6.x,res_7.x,res_9.x,res_10.x,res_11.x,res_13.x,res_15.x,res_16.x])
print (P[:,0])
print (np.mean(P[:,0]))
print (P[:,1])
print (np.mean(P[:,1]))
print (P[:,2])
print (np.mean(P[:,2]))
print (P[:,3])
print (np.mean(P[:,3]))
print (P[:,4])
print (np.mean(P[:,4]))
print (P[:,5])
print (np.mean(P[:,5]))
print (P[:,6])
print (np.mean(P[:,6]))
# Out:
# [0.66992342 0.69905492 0.84748047 0.64470032 0.69901615 0.73049965
#  0.64629496 0.69902714 0.7305705  0.7186619  0.67153053 0.64460531]
# 0.7001137726838235
# [0.91515549 0.94993412 0.9448945  0.90922087 0.94999181 0.94981057
#  0.86381069 0.94999096 0.94960287 0.94954233 0.88913388 0.80542345]
# 0.918875962837363
# [0.59577581 0.65398665 0.62941964 0.56477752 0.6544556  0.63004312
#  0.5408938  0.65465181 0.63004437 0.62985221 0.5831192  0.57005098]
# 0.6114225588941021
# [0.53576466 0.5495844  0.54988565 0.51855867 0.54938406 0.55018273
#  0.51578534 0.54919104 0.55011538 0.55000624 0.52958495 0.52112054]
# 0.5390969708780767
# [0.82791742 0.82994742 0.82975315 0.82565235 0.82991759 0.82998887
#  0.82078298 0.82991472 0.8299764  0.82998295 0.82525441 0.82386257]
# 0.8277459030029507
# [0.73547037 0.73097937 0.73309505 0.74024788 0.7310287  0.73018246
#  0.74276358 0.7309697  0.73026787 0.73007469 0.73815839 0.73968067]
# 0.7344098943116831
# [0.06895423 0.0636644  0.07008756 0.14190173 0.06311244 0.06111456
#  0.12826468 0.06284495 0.06152244 0.06413674 0.10489174 0.12068664]
# 0.08426517745020058

# %%
P
# Out:
# array([[0.66992342, 0.91515549, 0.59577581, 0.53576466, 0.82791742,
#         0.73547037, 0.06895423],
#        [0.69905492, 0.94993412, 0.65398665, 0.5495844 , 0.82994742,
#         0.73097937, 0.0636644 ],
#        [0.84748047, 0.9448945 , 0.62941964, 0.54988565, 0.82975315,
#         0.73309505, 0.07008756],
#        [0.64470032, 0.90922087, 0.56477752, 0.51855867, 0.82565235,
#         0.74024788, 0.14190173],
#        [0.69901615, 0.94999181, 0.6544556 , 0.54938406, 0.82991759,
#         0.7310287 , 0.06311244],
#        [0.73049965, 0.94981057, 0.63004312, 0.55018273, 0.82998887,
#         0.73018246, 0.06111456],
#        [0.64629496, 0.86381069, 0.5408938 , 0.51578534, 0.82078298,
#         0.74276358, 0.12826468],
#        [0.69902714, 0.94999096, 0.65465181, 0.54919104, 0.82991472,
#         0.7309697 , 0.06284495],
#        [0.7305705 , 0.94960287, 0.63004437, 0.55011538, 0.8299764 ,
#         0.73026787, 0.06152244],
#        [0.7186619 , 0.94954233, 0.62985221, 0.55000624, 0.82998295,
#         0.73007469, 0.06413674],
#        [0.67153053, 0.88913388, 0.5831192 , 0.52958495, 0.82525441,
#         0.73815839, 0.10489174],
#        [0.64460531, 0.80542345, 0.57005098, 0.52112054, 0.82386257,
#         0.73968067, 0.12068664]])
